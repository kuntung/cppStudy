// %% [markdown]
// # 函数提高

// %% [markdown]
// ## 函数的默认参数
// 在c++中，函数的形参列表中是可以有默认值的
// ```cpp
// 返回值类型 函数名(数据类型 形参 = 默认值){}
// ```
// 注意事项：
// 1. 如果某个位置已经有了默认参数，那么从这个位置往后，从左往右都应该有默认值
// 2. 如果函数声明有默认参数，那么函数实现就不能有默认参数 *默认参数只能定义一次，避免出现歧义*
// 3. 声明和实现只能有一个默认参数

// %%
//函数的默认参数代码示例
#include<iostream> 

using namespace std;

// %%
int func(int a, int b, int c){
    
    return a + b + c;
}

cout<<func(1, 2, 3);
// Out:
// 6

// %%
//如果我们自己传入数据，就用自己的数据，如果没有，就用默认值
int func1(int a, int b = 3, int c = 4){
    
    return a + b + c;
}
cout<<func1(1);
// Out:
// 8

// %% [markdown]
// ## 函数占位参数
// c++中函数的形参列表里可以有占位参数，用来做占位，调用函数时必须填补该位置
// ```cpp
// 返回值类型 函数名(数据类型){}
// ```
// 占位参数还可以有默认参数
// ```cpp
// void func(int a, int = 10){}
// ```

// %%
//占位参数代码示例
void func3(int a, int){
    
    cout<<"占位参数示例";
    cout<<endl;
}
func3(10, 20);
// func3(10);//报错，必须将占位参数填补
// Out:
// 占位参数示例

// %% [markdown]
// ## 函数重载
// 函数名可以相同，提高复用性
//
// **函数重载满足条件**
// 1. 同一个作用域下
// 2. 函数名相同
// 3. 函数`参数类型`、`个数`，`顺序`不同（函数重载的条件：函数参数）
// 4. 函数的返回值不可以作为函数重载的条件

// %%
//函数重载代码示例
void funcOld(){
    
    cout<<"函数重载前"<<"\n";
}

// %%
void funcOld(int a){
    
    cout<<"函数重载后"<<"\n";
}

// %%
funcOld();
funcOld(3);
// Out:
// 函数重载前
// 函数重载后

// %% [markdown]
// ### 函数重载注意事项
// 1. 引用作为重载条件
// 2. 函数重载与默认参数，`容易出现二义性`

// %%
//引用作为重载条件
void func(int &a){
    
    cout<<"func(int &a)的调用"<<"\n";
}

// %%
void func(const int &a){
    
    cout<<"func(cons int &a)的调用"<<"\n";
}

// %%
int a = 10;

func(a);
func(10);//调用常量引用的格式，不会调用第一个，因为int &a = 10;不合法，10是一块临时空间
// Out:
// func(int &a)的调用
// func(cons int &a)的调用

// %%
//重载与默认参数
//函数带有默认参数的情形
void func2(int a, int b = 10){
    cout<<"func2(int a, int b = 10)的调用"<<"\n";
}

// %%
//函数不带默认参数的情形
void func2(int a){
    cout<<"func2(int a)的调用"<<"\n";
}

// %%
func2(10);//报错，出现歧义
// Out:
// input_line_37:2:2: error: call to 'func2' is ambiguous
//  func2(10);//报错，出现歧义
//  ^~~~~
// input_line_34:3:6: note: candidate function
// void func2(int a, int b = 10){
//      ^
// input_line_35:2:6: note: candidate function
// void func2(int a){
//      ^
// Interpreter Error:
