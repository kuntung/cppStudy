// %% [markdown]
// # 基本知识点

// %% [markdown]
// ## 常量指针和指针常量

// %% [markdown]
// ## 传`const char *`和`const string &`的区别

// %% [markdown]
// ## vector与普通数组的区别
// 不同之处在于：数组是静态空间，而vector可以`动态扩展`
//
// 动态扩展：
// 并不是在原空间之后续接新空间，而是找更大的内存空间，然后将原数据拷贝到新空间，然后释放原有空间
//
// <img src = "attachment:58e5ba6f-b194-434f-929b-71708dab1dea.png" width = "400" height = "200"/>

// %% [markdown]
// ## C++匿名对象
